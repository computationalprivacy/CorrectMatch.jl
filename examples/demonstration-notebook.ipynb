# %%
using CorrectMatch
using StatsBase
using CSV
using CodecZlib
using DataFrames
using Distributions

# %%
# Read CSV file
df = CSV.read("adults.csv", DataFrame)

# %%
# Select columns
df_sub = df[:, [:age, :sex, :workclass, :relationship, Symbol("marital-status"), :race]]
N = nrow(df_sub)

# %% [markdown]
# ## Estimating population uniqueness

# %%
# True population uniqueness
u = uniqueness(df_sub)
println("True population uniqueness: $u")

# %%
# Fit model directly on DataFrame
G = fit_mle(GaussianCopula, df_sub)
u = uniqueness(rand(G, N))
println("Estimated population uniqueness: $u")

# %%
# Fit model on 325 records (1% of the original data) and estimate uniqueness
ix = sample(1:N, 325; replace=false)
G_sample = fit_mle(GaussianCopula, df_sub[ix, :])
u = uniqueness(rand(G_sample, N))
println("Estimated population uniqueness (1% sample): $u")

# %% [markdown]
# ## Estimating individual uniqueness

# %%
# Fit model on full data
G = fit_mle(GaussianCopula, df_sub)

# %% [markdown]
# ### Likely unique individual

# %%
# Get first individual - 39 years old male with non Asian/Black/White race
indiv = df_sub[1, :]

# %%
individual_uniqueness(G, indiv, N)

# %%
individual_correctness(G, indiv, N)

# %% [markdown]
# ### Unlikely unique individual

# %%
# 30 years old white male
indiv = df_sub[12, :]

# %%
individual_uniqueness(G, indiv, N)

# %%
individual_correctness(G, indiv, N)
